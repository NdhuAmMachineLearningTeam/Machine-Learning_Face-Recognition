# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

PATH = "C:/Users/Mr-Fish/Desktop/Face Database/"
img = mpimg.imread(PATH + "s01_01.jpg")

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img.shape
# Out:
# (241, 181, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 86,  63,  55],
#         [ 84,  59,  52],
#         [ 88,  61,  54],
#         ...,
#         [ 90,  65,  58],
#         [ 80,  55,  48],
#         [ 78,  55,  47]],
#
#        [[ 97,  72,  65],
#         [ 85,  58,  51],
#         [ 79,  52,  45],
#         ...,
#         [ 93,  68,  61],
#         [ 84,  59,  52],
#         [ 77,  52,  45]],
#
#        [[108,  84,  74],
#         [108,  81,  72],
#         [ 97,  70,  61],
#         ...,
#         [ 95,  70,  63],
#         [ 87,  62,  55],
#         [ 78,  53,  46]],
#
#        ...,
#
#        [[ 77,  52,  32],
#         [ 84,  59,  39],
#         [ 80,  54,  37],
#         ...,
#         [ 57,  40,  20],
#         [ 52,  35,  15],
#         [ 56,  39,  19]],
#
#        [[ 77,  51,  34],
#         [ 82,  56,  39],
#         [ 82,  56,  39],
#         ...,
#         [ 58,  41,  21],
#         [ 57,  40,  20],
#         [ 58,  41,  21]],
#
#        [[ 77,  52,  32],
#         [ 81,  56,  36],
#         [ 85,  59,  42],
# ...

# %%
import os
train_data = []
for file in os.listdir(PATH):
    img = mpimg.imread(PATH + file)
    train_data.append(img)

# %%
type(train_data)
# Out:
# list

# %%
type(train_data[0])
# Out:
# numpy.ndarray

# %%
len(train_data)
# Out:
# 650

# %%
train_data[0].shape
# Out:
# (241, 181, 3)

# %%
plt.imshow(train_data[0])
plt.axis('off')
plt.show()

# %%
size = []
for i in range(650):
    size.append(train_data[i].size)
size = np.array(size)

# %%
np.argmax(size)
# Out:
# 91

# %%
np.argmin(size)
# Out:
# 164

# %%
print(train_data[91].shape)
print(train_data[164].shape)
# Out:
# (311, 201, 3)
# (156, 116, 3)

# %%
import cv2
a = cv2.resize(train_data[0],(116,156),interpolation=cv2.INTER_AREA)

# %%
a.shape
# Out:
# (156, 116, 3)

# %%
plt.imshow(a)
plt.axis('off')
plt.show()

# %%
b = cv2.resize(train_data[0],(201,311),interpolation=cv2.INTER_CUBIC)
print(b.shape)
# Out:
# (311, 201, 3)

# %%
plt.imshow(b)
plt.axis('off')
plt.show()

# %%
shape = train_data[0].shape
print(shape[0])
print(shape[1])
# Out:
# 241
# 181

# %%
ratio = []
for i in range(650):
    shape = train_data[i].shape
    ratio.append(shape[0]/shape[1])
ratio = np.array(ratio)

# %%
np.mean(ratio)
# Out:
# 1.4622902940076956

# %%
311/np.mean(ratio)
# Out:
# 212.68006857081915

# %%
c = cv2.resize(train_data[0],(213,311),interpolation=cv2.INTER_CUBIC)
print(c.shape)
# Out:
# (311, 213, 3)

# %%
plt.imshow(b)
plt.axis('off')
plt.show()

# %%
for i in range(650):
    train_data[i] = cv2.resize(train_data[i],(213,311),interpolation=cv2.INTER_CUBIC)

# %%
for i in range(100,110):
    print(train_data[i].shape)
# Out:
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)
# (311, 213, 3)

# %%
train_data = np.array(train_data)

# %%
train_data.shape
# Out:
# (650, 311, 213, 3)
